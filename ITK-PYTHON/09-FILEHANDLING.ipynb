# %%
print("="*50)
print("Student Login")
print("="*50)

student = input("Enter your name: ")
print(f"Welcome {student}")
print(f"Program finsihed")
# Out:
# ...
# Student Login
# ...
# Welcome Manoj
# Program finsihed

# %%
student
# Out:
# 'Manoj'

# %%
student
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/opt/python@3.12/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
print("="*50)
print("Student Login")
print("="*50)

student = input("Enter your name: ")

with open("student.txt","w") as file:
    file.write(student)
print(f"Welcome {student}")
print(f"Program finsihed")
# Out:
# ...
# Student Login
# ...
# Welcome itk
# Program finsihed

# %%
file = open("notes.txt",'w')
file.write("We are from Itkannadigaru and we are working complete ai full course...")
file.close()

# %%
file =open("notes.txt",'w')
print(10/0)
file.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 file =open("notes.txt",'w')
# ----> 2 print(10/0)
#       3 file.close()
#
# ZeroDivisionError: division by zero

# %%
try:
    file =open("notes.txt",'w')
    file.write("Hello")
finally:
    file.close()

# %%
try:
    file =open("notes.txt",'w')
    print(10/0)
except ZeroDivisionError: 
    print("this error")
finally:
    file.close()
# Out:
# this error

# %%
# file writing methods
# Mode "w" -> write (create new/overwrite existing content)
# Mode "a" -> append (add to an existing content)
# Mode "r" -> read()

# %%
with open("notes.txt","w") as file:
    file.write("this to exaplian with function....")

# %%
with open("notes.txt","w") as file:
    file.write("this to exaplian with function....")
    file.write("am learning i/o file")
    file.write("this is saved on disk")

print("files written")
# Out:
# files written

# %%
with open("notes.txt","w") as file:
    file.write("this to exaplian with function....\n")
    file.write("am learning i/o file\n")
    file.write("this is saved on disk\n")

print("files written")
# Out:
# files written

# %%
# Read file
with open("notes.txt","r") as file:
    content = file.read()
    print("file contensts")
    print(content)
# Out:
# file contensts
# this to exaplian with function....
# am learning i/o file
# this is saved on disk

# %%
with open("notes.txt","r") as file:
    file.read()

# %%
with open("notes.txt","r") as file:
    print("line by line")
    for line_num,line in enumerate(file,start=1):
        print(f"Line is {line_num}: {line.strip()} ")
# Out:
# line by line
# Line is 1: this to exaplian with function....
# Line is 2: am learning i/o file
# Line is 3: this is saved on disk

# %%
with open("notes.txt","a") as file:
    file.write("this to exaplian with function.... and am using append mode \n")

# %%
with open("amazing.txt","r") as file:
    file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with open("amazing.txt","r") as file:
#       2     file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'amazing.txt'

# %%
def read_file_safe(filename):
    try:
       with open(filename,"r") as file:
            return file.read() 
    except FileNotFoundError:
        print(f"❌ file {filename} not found")
        return None
    except PermissionError:
        print(f"❌ No persmission to read {filename}")
        return None

# %%
read_file_safe("/Users/manojkrishnappa/github/ITK-COMPLETE-GENAI-SERIES/ITK-PYTHON/notes.txt")
# Out:
# 'this to exaplian with function....\nam learning i/o file\nthis is saved on disk\nthis to exaplian with function.... and am using append mode \n'

# %%
read_file_safe("notes.txt")
# Out:
# 'this to exaplian with function....\nam learning i/o file\nthis is saved on disk\nthis to exaplian with function.... and am using append mode \n'

# %%
read_file_safe("test.sh")
# Out:
# ❌ file test.sh not found

# %% [markdown]
# # Build: College Result Portal with File Storage

# %% [markdown]
# ```
# Features:
# 1. Store student data in "results.json"
# 2. Add student: name, roll, marks for 5 subjects
# 3. View result: formatted mark sheet with pass/fail, grade, rank
# 4. Update marks: safely update one subject's marks
# 5. Delete student: with confirmation prompt
# 6. Export to "results.txt": formatted text report for printing
# 7. Handle all errors: invalid roll number, file issues, bad input
#
# Exception handling required:
# - User enters non-numeric marks → catch ValueError, ask again
# - JSON file corrupted → show warning, start fresh
# - Student roll not found → show "Student not found"
# - File write fails → show error, don't crash
# ```

# %%
print
