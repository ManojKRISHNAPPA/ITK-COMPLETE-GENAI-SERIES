# %%
import os

# %%
num  = 5
square = num * num

# %%
square
# Out:
# 25

# %%
#calculating the cube

num  = 5
cube = num * num * num
print(cube)
# Out:
# 125

# %%
# aeea of circle

radius = 5
pi = 3.14

area = pi * radius * radius

print(area)
# Out:
# 78.5

# %%
number = 16
guess = number/2

for i in range(10):
    guess = (guess + number/guess) /2

print(guess)
# Out:
# 4.0

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
import math

print(math.__file__)
# Out:
# /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload/math.cpython-312-darwin.so

# %%
import random

print(random.__file__)
# Out:
# /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/random.py

# %%
from math import sqrt
print(sqrt(10))
# Out:
# 3.1622776601683795

# %%
from math import sqrt, pi
print(sqrt(10))
print(pi)
# Out:
# 3.1622776601683795
# 3.141592653589793

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *

sqrt(10)
pi
# Out:
# 3.141592653589793

# %%
import calculator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import calculator
#
# ModuleNotFoundError: No module named 'calculator'

# %%
from module.calculator import add
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from module.calculator import add
#
# ModuleNotFoundError: No module named 'module'

# %%
from package.subpackage.calculator import greet

greet("manoj")
# Out:
# 'welcom manoj'
