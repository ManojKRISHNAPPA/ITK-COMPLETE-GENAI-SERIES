# %%
# simple coding

# %%
# call the endpoint

# %%
print("rest in piece")
print("Hello wor")
# Out:
# rest in piece
# Hello wor

# %%
order_items = ["butter_chicken","Naan","chiken_biriyani","veg_biriyani","panner tikka"]

# %%
order_items
# Out:
# ['butter_chicken', 'Naan', 'chiken_biriyani', 'veg_biriyani', 'panner tikka']

# %%
print("order items are:", order_items)
# Out:
# order items are: ['butter_chicken', 'Naan', 'chiken_biriyani', 'veg_biriyani', 'panner tikka']

# %%
order_items[1]
# Out:
# 'Naan'

# %%
order_items[2]
# Out:
# 'chiken_biriyani'

# %%
import langchain


langchain.ofmpt
